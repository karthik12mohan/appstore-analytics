# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score
import matplotlib.pyplot as p
import numpy as np
import seaborn as sns
import os

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
ap=pd.read_csv(r"C:\Users\karth\Desktop\AppleStore.csv")

# %%
ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 17 columns):
# Unnamed: 0          7197 non-null int64
# id                  7197 non-null int64
# track_name          7197 non-null object
# size_bytes          7197 non-null int64
# currency            7197 non-null object
# price               7197 non-null float64
# rating_count_tot    6268 non-null float64
# rating_count_ver    5754 non-null float64
# user_rating         6268 non-null float64
# user_rating_ver     5754 non-null float64
# ver                 7197 non-null object
# cont_rating         7197 non-null object
# prime_genre         7197 non-null object
# sup_devices.num     7197 non-null int64
# ipadSc_urls.num     5810 non-null float64
# lang.num            7156 non-null float64
# vpp_lic             7197 non-null int64
# dtypes: float64(7), int64(5), object(5)
# memory usage: 955.9+ KB

# %%
ap.shape
# Out:
# (7197, 17)

# %%
ap.describe()
# Out:
#         Unnamed: 0            id    size_bytes        price  rating_count_tot  \
# count  7197.000000  7.197000e+03  7.197000e+03  7197.000000      6.268000e+03
# mean   3598.000000  8.631310e+08  1.991345e+08     1.726218      1.480381e+04
# std    2077.739276  2.712368e+08  3.592069e+08     5.833006      8.098468e+04
# min       0.000000  2.816565e+08  5.898240e+05     0.000000      1.000000e+00
# 25%    1799.000000  6.000937e+08  4.692275e+07     0.000000      7.800000e+01
# 50%    3598.000000  9.781482e+08  9.715302e+07     0.000000      5.125000e+02
# 75%    5397.000000  1.082310e+09  1.819249e+08     1.990000      3.963500e+03
# max    7196.000000  1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       5754.000000  6268.000000      5754.000000      7197.000000
# mean         575.827424     4.049697         4.069517        37.361817
# std         4377.060487     0.726943         0.879711         3.737715
# min            1.000000     1.000000         1.000000         9.000000
# 25%           10.000000     4.000000         4.000000        37.000000
# 50%           49.000000     4.500000         4.500000        37.000000
# 75%          205.000000     4.500000         4.500000        38.000000
# max       177050.000000     5.000000         5.000000        47.000000
#
#        ipadSc_urls.num     lang.num      vpp_lic
# count      5810.000000  7156.000000  7197.000000
# mean          4.592083     5.466042     0.993053
# std           0.906285     7.931527     0.083066
# min           1.000000     1.000000     0.000000
# 25%           5.000000     1.000000     1.000000
# 50%           5.000000     1.000000     1.000000
# 75%           5.000000     8.000000     1.000000
# max           5.000000    75.000000     1.000000

# %%
ap.head(50)
# Out:
#     Unnamed: 0         id                                         track_name  \
# 0            0  281656475                                    PAC-MAN Premium
# 1            1  281796108                          Evernote - stay organized
# 2            2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3            3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4            4  282935706                                              Bible
# 5            5  283619399                                   Shanghai Mahjong
# 6            6  283646709             PayPal - Send and request money safely
# 7            7  284035177                            Pandora - Music & Radio
# 8            8  284666222                        PCalc - The Best Calculator
# 9            9  284736660                                        Ms. PAC-MAN
# 10          10  284791396                          Solitaire by MobilityWare
# 11          11  284815117                                   SCRABBLE Premium
# 12          12  284815942               Google – Search made just for mobile
# 13          13  284847138                   Bank of America - Mobile Banking
# 14          14  284862767                                           FreeCell
# 15          15  284876795             TripAdvisor Hotels Flights Restaurants
# 16          16  284882215                                           Facebook
# 17          17  284910350     Yelp - Nearby Restaurants, Shopping & Services
# 18          18  284993459  Shazam - Discover music, artists, videos & lyrics
# 19          19  285005463                      Crash Bandicoot Nitro Kart 3D
# 20          20  285946052                                             iQuran
# 21          21  285994151                                        :) Sudoku +
# 22          22  286058814    Yahoo Sports - Teams, Scores, News & Highlights
# 23          23  286070473                          Mileage Log | Fahrtenbuch
# 24          24  286799607                        Cleartune - Chromatic Tuner
# 25          25  286906691          Lifesum – Inspiring healthy lifestyle app
# 26          26  286911400                                           Hangman.
# 27          27  288113403      iTranslate - Language Translator & Dictionary
# 28          28  288120394                                           TouchOSC
# 29          29  288419283                                         RadarScope
# 30          30  288429040                                           LinkedIn
# 31          31  289084315                              Period Tracker Deluxe
# 32          32  289446241                                  Election 2016 Map
# 33          33  289523017                          Blackjack by MobilityWare
# 34          34  289894882                                        White Noise
# 35          35  290638154          iHeartRadio – Free Music & Radio Stations
# 36          36  290807369                                  Line Rider iRide™
# 37          37  290986013                      Deliveries: a package tracker
# 38          38  291430598                                      Hurricane Pro
# 39          39  292421271                                       Fieldrunners
# 40          40  292628469                                         Juxtaposer
# 41          41  292738169  Deezer - Listen to your Favorite Music & Playl...
# 42          42  293118835                                           iStellar
# 43          43  293523031                                   Sonos Controller
# 44          44  293573778                                          Avertinoo
# 45          45  293622097                                       Google Earth
# 46          46  293760823               iFart - The Original Fart Sounds App
# 47          47  293778748                                            PAC-MAN
# 48          48  294056623                                  FOX Sports Mobile
# 49          49  294536447                                First Words Animals
#
#     size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0    100788224      USD   3.99           21292.0              26.0
# 1    158578688      USD   0.00          161065.0              26.0
# 2    100524032      USD   0.00          188583.0            2822.0
# 3    128512000      USD   0.00          262241.0             649.0
# 4     92774400      USD   0.00          985920.0            5320.0
# 5     10485713      USD   0.99            8253.0            5516.0
# 6    227795968      USD   0.00          119487.0             879.0
# 7    130242560      USD   0.00         1126879.0            3594.0
# 8     49250304      USD   9.99            1117.0               4.0
# 9     70023168      USD   3.99            7885.0              40.0
# 10    49618944      USD   4.99           76720.0            4017.0
# 11   227547136      USD   7.99          105776.0             166.0
# 12   179979264      USD   0.00          479440.0             203.0
# 13   160925696      USD   0.00          119773.0            2336.0
# 14    55153664      USD   4.99            6340.0             668.0
# 15   207907840      USD   0.00           56194.0              87.0
# 16   389879808      USD   0.00         2974676.0             212.0
# 17   167407616      USD   0.00          223885.0            3726.0
# 18   147093504      USD   0.00          402925.0             136.0
# 19    10735026      USD   2.99           31456.0            4178.0
# 20    70707916      USD   1.99            2929.0             966.0
# 21     6169600      USD   2.99           11447.0             781.0
# 22   130583552      USD   0.00          137951.0             131.0
# 23    71203840      USD   5.99               8.0               NaN
# 24    11423008      USD   3.99            3241.0             297.0
# 25   188017664      USD   0.00            5795.0              12.0
# 26     4765696      USD   0.00           42316.0             248.0
# 27   287933440      USD   0.00          123215.0              25.0
# 28     4263936      USD   4.99             782.0               7.0
# 29   172772352      USD   9.99            3449.0              23.0
# 30   273844224      USD   0.00           71856.0              62.0
# 31    40216576      USD   1.99           13350.0             489.0
# 32     2386944      USD   0.99             137.0               NaN
# 33   105431040      USD   0.00          180087.0            1101.0
# 34    44129280      USD   0.99           33426.0             299.0
# 35   116443136      USD   0.00          293228.0             110.0
# 36     1646592      USD   1.99           21609.0              69.0
# 37    30016512      USD   4.99            4684.0              10.0
# 38    29518848      USD   2.99            2104.0               NaN
# 39    66872320      USD   2.99           41633.0               6.0
# 40    45229056      USD   2.99            3610.0               7.0
# 41   127470592      USD   0.00            4677.0              12.0
# 42    44241920      USD   3.99              30.0               NaN
# 43   107983872      USD   0.00           48905.0            2691.0
# 44     8044544      USD   4.99              32.0               NaN
# 45    37214208      USD   0.00          446185.0            1359.0
# 46    60320768      USD   1.99           21825.0              10.0
# 47   100849664      USD   0.00          508808.0              99.0
# 48    72748032      USD   0.00           57500.0             103.0
# 49    32164864      USD   1.99            2576.0               4.0
#
#     user_rating  user_rating_ver         ver cont_rating        prime_genre  \
# 0           4.0              4.5       6.3.5          4+              Games
# 1           4.0              3.5       8.2.2          4+       Productivity
# 2           3.5              4.5       5.0.0          4+            Weather
# 3           4.0              4.5      5.10.0         12+           Shopping
# 4           4.5              5.0       7.5.1          4+          Reference
# 5           4.0              4.0         1.8          4+              Games
# 6           4.0              4.5      6.12.0          4+            Finance
# 7           4.0              4.5       8.4.1         12+              Music
# 8           4.5              5.0       3.6.6          4+          Utilities
# 9           4.0              4.0       4.0.4          4+              Games
# 10          4.5              4.5      4.10.1          4+              Games
# 11          3.5              2.5      5.19.0          4+              Games
# 12          3.5              4.0          27         17+          Utilities
# 13          3.5              4.5       7.3.8          4+            Finance
# 14          4.5              4.5       4.0.3          4+              Games
# 15          4.0              3.5        21.1          4+             Travel
# 16          3.5              3.5          95          4+  Social Networking
# 17          4.0              4.5     11.15.0         12+             Travel
# 18          4.0              4.5      11.0.3         12+              Music
# 19          4.0              3.5       1.0.0          4+              Games
# 20          4.5              4.5         3.3          4+          Reference
# 21          5.0              5.0       5.2.6          4+              Games
# 22          4.0              4.5         6.9          4+             Sports
# 23          4.5              NaN       9.0.5          4+           Business
# 24          4.0              4.0       2.1.3          4+              Music
# 25          3.5              4.0       8.4.1          4+   Health & Fitness
# 26          3.0              3.5       2.0.6          9+              Games
# 27          3.5              5.0      10.5.4          4+       Productivity
# 28          4.0              3.5       1.9.8          4+              Music
# 29          4.0              4.5       3.4.1          4+            Weather
# 30          3.5              4.5      9.1.32          4+  Social Networking
# 31          4.5              5.0         9.6         12+   Health & Fitness
# 32          3.0              NaN           5          4+      Entertainment
# 33          3.5              4.5       5.5.3         12+              Games
# 34          4.0              5.0         7.2          4+   Health & Fitness
# 35          4.0              3.0       8.0.0         12+              Music
# 36          3.5              2.5         2.4          9+      Entertainment
# 37          4.0              4.0       8.0.3          4+          Utilities
# 38          4.5              NaN         5.2         17+            Weather
# 39          4.0              3.0  1.7.177604          9+              Games
# 40          4.5              5.0       3.8.2          4+      Photo & Video
# 41          3.0              4.0      6.19.0         12+              Music
# 42          3.5              NaN       2.9.0          4+         Navigation
# 43          4.5              4.5         7.2          4+              Music
# 44          3.0              NaN       3.9.2          4+         Navigation
# 45          3.5              3.5       7.1.6          4+             Travel
# 46          3.0              4.0       4.0.8          9+      Entertainment
# 47          3.0              4.5       6.3.5          4+              Games
# 48          3.0              4.0      3.5.13          4+             Sports
# 49          4.0              5.0           7          4+              Games
#
#     sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0                38              5.0      10.0        1
# 1                37              5.0      23.0        1
# 2                37              5.0       3.0        1
# 3                37              5.0       9.0        1
# 4                37              5.0      45.0        1
# 5                47              5.0       1.0        1
# 6                37              NaN      19.0        1
# 7                37              4.0       1.0        1
# 8                37              5.0       1.0        1
# 9                38              NaN      10.0        1
# 10               38              4.0      11.0        1
# 11               37              NaN       6.0        1
# 12               37              4.0      33.0        1
# 13               37              NaN       2.0        1
# 14               38              5.0       2.0        1
# 15               37              1.0      26.0        1
# 16               37              1.0      29.0        1
# 17               37              5.0      18.0        1
# 18               37              3.0      16.0        1
# 19               47              NaN       1.0        1
# 20               43              NaN       2.0        1
# 21               40              5.0       1.0        1
# 22               37              2.0       6.0        1
# 23               37              5.0       3.0        1
# 24               43              2.0      10.0        1
# 25               37              5.0      11.0        1
# 26               38              NaN       1.0        1
# 27               37              5.0      23.0        1
# 28               43              1.0       1.0        1
# 29               37              5.0       1.0        1
# 30               37              2.0      23.0        1
# 31               38              NaN      15.0        1
# 32               37              1.0       1.0        1
# 33               37              5.0       5.0        1
# 34               37              5.0       3.0        1
# 35               37              5.0       2.0        1
# 36               40              NaN       1.0        1
# 37               37              4.0       9.0        1
# 38               37              NaN       1.0        1
# 39               37              NaN       1.0        1
# 40               37              5.0       1.0        1
# 41               37              5.0      21.0        1
# 42               37              NaN       2.0        0
# 43               37              4.0      12.0        1
# 44               38              5.0       7.0        1
# 45               43              5.0      30.0        1
# 46               37              5.0       1.0        1
# 47               38              5.0      10.0        1
# 48               37              NaN       1.0        0
# 49               38              5.0       1.0        1

# %%
ap.isnull().sum()  # checks for the total null values
# Out:
# Unnamed: 0             0
# id                     0
# track_name             0
# size_bytes             0
# currency               0
# price                  0
# rating_count_tot     929
# rating_count_ver    1443
# user_rating          929
# user_rating_ver     1443
# ver                    0
# cont_rating            0
# prime_genre            0
# sup_devices.num        0
# ipadSc_urls.num     1387
# lang.num              41
# vpp_lic                0
# dtype: int64

# %%
ap.columns
# Out:
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
col=['rating_count_tot','rating_count_ver']

# %%
for j in col:
    ap[j]=ap[j].fillna(ap[j].mean()) #replace the null values by their mean

# %%
ap.isnull().sum()
# Out:
# Unnamed: 0             0
# id                     0
# track_name             0
# size_bytes             0
# currency               0
# price                  0
# rating_count_tot       0
# rating_count_ver       0
# user_rating          929
# user_rating_ver     1443
# ver                    0
# cont_rating            0
# prime_genre            0
# sup_devices.num        0
# ipadSc_urls.num     1387
# lang.num              41
# vpp_lic                0
# dtype: int64

# %%
ap.fillna(method='ffill', inplace=True) # replace remaining null values by previous value

# %%
ap.isnull().sum()
# Out:
# Unnamed: 0          0
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# dtype: int64

# %%
ap.head(50)
# Out:
#     Unnamed: 0         id                                         track_name  \
# 0            0  281656475                                    PAC-MAN Premium
# 1            1  281796108                          Evernote - stay organized
# 2            2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3            3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4            4  282935706                                              Bible
# 5            5  283619399                                   Shanghai Mahjong
# 6            6  283646709             PayPal - Send and request money safely
# 7            7  284035177                            Pandora - Music & Radio
# 8            8  284666222                        PCalc - The Best Calculator
# 9            9  284736660                                        Ms. PAC-MAN
# 10          10  284791396                          Solitaire by MobilityWare
# 11          11  284815117                                   SCRABBLE Premium
# 12          12  284815942               Google – Search made just for mobile
# 13          13  284847138                   Bank of America - Mobile Banking
# 14          14  284862767                                           FreeCell
# 15          15  284876795             TripAdvisor Hotels Flights Restaurants
# 16          16  284882215                                           Facebook
# 17          17  284910350     Yelp - Nearby Restaurants, Shopping & Services
# 18          18  284993459  Shazam - Discover music, artists, videos & lyrics
# 19          19  285005463                      Crash Bandicoot Nitro Kart 3D
# 20          20  285946052                                             iQuran
# 21          21  285994151                                        :) Sudoku +
# 22          22  286058814    Yahoo Sports - Teams, Scores, News & Highlights
# 23          23  286070473                          Mileage Log | Fahrtenbuch
# 24          24  286799607                        Cleartune - Chromatic Tuner
# 25          25  286906691          Lifesum – Inspiring healthy lifestyle app
# 26          26  286911400                                           Hangman.
# 27          27  288113403      iTranslate - Language Translator & Dictionary
# 28          28  288120394                                           TouchOSC
# 29          29  288419283                                         RadarScope
# 30          30  288429040                                           LinkedIn
# 31          31  289084315                              Period Tracker Deluxe
# 32          32  289446241                                  Election 2016 Map
# 33          33  289523017                          Blackjack by MobilityWare
# 34          34  289894882                                        White Noise
# 35          35  290638154          iHeartRadio – Free Music & Radio Stations
# 36          36  290807369                                  Line Rider iRide™
# 37          37  290986013                      Deliveries: a package tracker
# 38          38  291430598                                      Hurricane Pro
# 39          39  292421271                                       Fieldrunners
# 40          40  292628469                                         Juxtaposer
# 41          41  292738169  Deezer - Listen to your Favorite Music & Playl...
# 42          42  293118835                                           iStellar
# 43          43  293523031                                   Sonos Controller
# 44          44  293573778                                          Avertinoo
# 45          45  293622097                                       Google Earth
# 46          46  293760823               iFart - The Original Fart Sounds App
# 47          47  293778748                                            PAC-MAN
# 48          48  294056623                                  FOX Sports Mobile
# 49          49  294536447                                First Words Animals
#
#     size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0    100788224      USD   3.99           21292.0         26.000000
# 1    158578688      USD   0.00          161065.0         26.000000
# 2    100524032      USD   0.00          188583.0       2822.000000
# 3    128512000      USD   0.00          262241.0        649.000000
# 4     92774400      USD   0.00          985920.0       5320.000000
# 5     10485713      USD   0.99            8253.0       5516.000000
# 6    227795968      USD   0.00          119487.0        879.000000
# 7    130242560      USD   0.00         1126879.0       3594.000000
# 8     49250304      USD   9.99            1117.0          4.000000
# 9     70023168      USD   3.99            7885.0         40.000000
# 10    49618944      USD   4.99           76720.0       4017.000000
# 11   227547136      USD   7.99          105776.0        166.000000
# 12   179979264      USD   0.00          479440.0        203.000000
# 13   160925696      USD   0.00          119773.0       2336.000000
# 14    55153664      USD   4.99            6340.0        668.000000
# 15   207907840      USD   0.00           56194.0         87.000000
# 16   389879808      USD   0.00         2974676.0        212.000000
# 17   167407616      USD   0.00          223885.0       3726.000000
# 18   147093504      USD   0.00          402925.0        136.000000
# 19    10735026      USD   2.99           31456.0       4178.000000
# 20    70707916      USD   1.99            2929.0        966.000000
# 21     6169600      USD   2.99           11447.0        781.000000
# 22   130583552      USD   0.00          137951.0        131.000000
# 23    71203840      USD   5.99               8.0        575.827424
# 24    11423008      USD   3.99            3241.0        297.000000
# 25   188017664      USD   0.00            5795.0         12.000000
# 26     4765696      USD   0.00           42316.0        248.000000
# 27   287933440      USD   0.00          123215.0         25.000000
# 28     4263936      USD   4.99             782.0          7.000000
# 29   172772352      USD   9.99            3449.0         23.000000
# 30   273844224      USD   0.00           71856.0         62.000000
# 31    40216576      USD   1.99           13350.0        489.000000
# 32     2386944      USD   0.99             137.0        575.827424
# 33   105431040      USD   0.00          180087.0       1101.000000
# 34    44129280      USD   0.99           33426.0        299.000000
# 35   116443136      USD   0.00          293228.0        110.000000
# 36     1646592      USD   1.99           21609.0         69.000000
# 37    30016512      USD   4.99            4684.0         10.000000
# 38    29518848      USD   2.99            2104.0        575.827424
# 39    66872320      USD   2.99           41633.0          6.000000
# 40    45229056      USD   2.99            3610.0          7.000000
# 41   127470592      USD   0.00            4677.0         12.000000
# 42    44241920      USD   3.99              30.0        575.827424
# 43   107983872      USD   0.00           48905.0       2691.000000
# 44     8044544      USD   4.99              32.0        575.827424
# 45    37214208      USD   0.00          446185.0       1359.000000
# 46    60320768      USD   1.99           21825.0         10.000000
# 47   100849664      USD   0.00          508808.0         99.000000
# 48    72748032      USD   0.00           57500.0        103.000000
# 49    32164864      USD   1.99            2576.0          4.000000
#
#     user_rating  user_rating_ver         ver cont_rating        prime_genre  \
# 0           4.0              4.5       6.3.5          4+              Games
# 1           4.0              3.5       8.2.2          4+       Productivity
# 2           3.5              4.5       5.0.0          4+            Weather
# 3           4.0              4.5      5.10.0         12+           Shopping
# 4           4.5              5.0       7.5.1          4+          Reference
# 5           4.0              4.0         1.8          4+              Games
# 6           4.0              4.5      6.12.0          4+            Finance
# 7           4.0              4.5       8.4.1         12+              Music
# 8           4.5              5.0       3.6.6          4+          Utilities
# 9           4.0              4.0       4.0.4          4+              Games
# 10          4.5              4.5      4.10.1          4+              Games
# 11          3.5              2.5      5.19.0          4+              Games
# 12          3.5              4.0          27         17+          Utilities
# 13          3.5              4.5       7.3.8          4+            Finance
# 14          4.5              4.5       4.0.3          4+              Games
# 15          4.0              3.5        21.1          4+             Travel
# 16          3.5              3.5          95          4+  Social Networking
# 17          4.0              4.5     11.15.0         12+             Travel
# 18          4.0              4.5      11.0.3         12+              Music
# 19          4.0              3.5       1.0.0          4+              Games
# 20          4.5              4.5         3.3          4+          Reference
# 21          5.0              5.0       5.2.6          4+              Games
# 22          4.0              4.5         6.9          4+             Sports
# 23          4.5              4.5       9.0.5          4+           Business
# 24          4.0              4.0       2.1.3          4+              Music
# 25          3.5              4.0       8.4.1          4+   Health & Fitness
# 26          3.0              3.5       2.0.6          9+              Games
# 27          3.5              5.0      10.5.4          4+       Productivity
# 28          4.0              3.5       1.9.8          4+              Music
# 29          4.0              4.5       3.4.1          4+            Weather
# 30          3.5              4.5      9.1.32          4+  Social Networking
# 31          4.5              5.0         9.6         12+   Health & Fitness
# 32          3.0              5.0           5          4+      Entertainment
# 33          3.5              4.5       5.5.3         12+              Games
# 34          4.0              5.0         7.2          4+   Health & Fitness
# 35          4.0              3.0       8.0.0         12+              Music
# 36          3.5              2.5         2.4          9+      Entertainment
# 37          4.0              4.0       8.0.3          4+          Utilities
# 38          4.5              4.0         5.2         17+            Weather
# 39          4.0              3.0  1.7.177604          9+              Games
# 40          4.5              5.0       3.8.2          4+      Photo & Video
# 41          3.0              4.0      6.19.0         12+              Music
# 42          3.5              4.0       2.9.0          4+         Navigation
# 43          4.5              4.5         7.2          4+              Music
# 44          3.0              4.5       3.9.2          4+         Navigation
# 45          3.5              3.5       7.1.6          4+             Travel
# 46          3.0              4.0       4.0.8          9+      Entertainment
# 47          3.0              4.5       6.3.5          4+              Games
# 48          3.0              4.0      3.5.13          4+             Sports
# 49          4.0              5.0           7          4+              Games
#
#     sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0                38              5.0      10.0        1
# 1                37              5.0      23.0        1
# 2                37              5.0       3.0        1
# 3                37              5.0       9.0        1
# 4                37              5.0      45.0        1
# 5                47              5.0       1.0        1
# 6                37              5.0      19.0        1
# 7                37              4.0       1.0        1
# 8                37              5.0       1.0        1
# 9                38              5.0      10.0        1
# 10               38              4.0      11.0        1
# 11               37              4.0       6.0        1
# 12               37              4.0      33.0        1
# 13               37              4.0       2.0        1
# 14               38              5.0       2.0        1
# 15               37              1.0      26.0        1
# 16               37              1.0      29.0        1
# 17               37              5.0      18.0        1
# 18               37              3.0      16.0        1
# 19               47              3.0       1.0        1
# 20               43              3.0       2.0        1
# 21               40              5.0       1.0        1
# 22               37              2.0       6.0        1
# 23               37              5.0       3.0        1
# 24               43              2.0      10.0        1
# 25               37              5.0      11.0        1
# 26               38              5.0       1.0        1
# 27               37              5.0      23.0        1
# 28               43              1.0       1.0        1
# 29               37              5.0       1.0        1
# 30               37              2.0      23.0        1
# 31               38              2.0      15.0        1
# 32               37              1.0       1.0        1
# 33               37              5.0       5.0        1
# 34               37              5.0       3.0        1
# 35               37              5.0       2.0        1
# 36               40              5.0       1.0        1
# 37               37              4.0       9.0        1
# 38               37              4.0       1.0        1
# 39               37              4.0       1.0        1
# 40               37              5.0       1.0        1
# 41               37              5.0      21.0        1
# 42               37              5.0       2.0        0
# 43               37              4.0      12.0        1
# 44               38              5.0       7.0        1
# 45               43              5.0      30.0        1
# 46               37              5.0       1.0        1
# 47               38              5.0      10.0        1
# 48               37              5.0       1.0        0
# 49               38              5.0       1.0        1

# %%
ap['rating_count_tot'].plot.hist()

# %%
ap['lang.num'].plot.hist()

# %%
ap['user_rating'].median()
# Out:
# 4.5

# %%
ap['user_rating'].plot.hist()

# %%
ap['user_rating_ver'].plot.hist()

# %%
ap['ipadSc_urls.num'].plot.hist()

# %%
ap['lang.num'].plot.hist()

# %%
ap['rating_count_tot'].plot.box()

# %%
ap['rating_count_ver'].plot.box()

# %%
ap['user_rating'].plot.box()

# %%
ap['user_rating_ver'].plot.box()

# %%
ap['ipadSc_urls.num'].plot.box()

# %%
ap['lang.num'].plot.box()

# %%
sns.distplot(ap['lang.num'])

# %%
ap['rating_count_ver'].plot.box()

# %%
ap.head(10)
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           0  281656475                                    PAC-MAN Premium
# 1           1  281796108                          Evernote - stay organized
# 2           2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           4  282935706                                              Bible
# 5           5  283619399                                   Shanghai Mahjong
# 6           6  283646709             PayPal - Send and request money safely
# 7           7  284035177                            Pandora - Music & Radio
# 8           8  284666222                        PCalc - The Best Calculator
# 9           9  284736660                                        Ms. PAC-MAN
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99           21292.0              26.0
# 1   158578688      USD   0.00          161065.0              26.0
# 2   100524032      USD   0.00          188583.0            2822.0
# 3   128512000      USD   0.00          262241.0             649.0
# 4    92774400      USD   0.00          985920.0            5320.0
# 5    10485713      USD   0.99            8253.0            5516.0
# 6   227795968      USD   0.00          119487.0             879.0
# 7   130242560      USD   0.00         1126879.0            3594.0
# 8    49250304      USD   9.99            1117.0               4.0
# 9    70023168      USD   3.99            7885.0              40.0
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
# 5          4.0              4.0     1.8          4+         Games
# 6          4.0              4.5  6.12.0          4+       Finance
# 7          4.0              4.5   8.4.1         12+         Music
# 8          4.5              5.0   3.6.6          4+     Utilities
# 9          4.0              4.0   4.0.4          4+         Games
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38              5.0      10.0        1
# 1               37              5.0      23.0        1
# 2               37              5.0       3.0        1
# 3               37              5.0       9.0        1
# 4               37              5.0      45.0        1
# 5               47              5.0       1.0        1
# 6               37              5.0      19.0        1
# 7               37              4.0       1.0        1
# 8               37              5.0       1.0        1
# 9               38              5.0      10.0        1

# %%
ap['price'].plot.hist(bins=range(0,25))

# %%
ap['lang.num'].hist()

# %%
ap['lang.num'].mean()
# Out:
# 5.461442267611504

# %%
ap['lang.num'].median()
# Out:
# 1.0

# %%
ap['lang.num'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
sns.jointplot(x='size_bytes',y='user_rating',data=ap,kind='scatter')

# %%
sns.jointplot(x='sup_devices.num',y='user_rating',data=ap,kind='scatter')

# %%
sns.jointplot(x='lang.num',y='user_rating',data=ap,kind='scatter')

# %%
sns.distplot(ap['lang.num'],kde=True,bins=10)

# %%
sns.distplot(ap['lang.num'],kde=False,bins=30)

# %%
sns.jointplot(x='size_bytes',y='price',data=ap,kind='scatter')

# %%
sns.jointplot(x='lang.num',y='size_bytes',data=ap,kind='hex')

# %%
from matplotlib import pyplot
from statsmodels.graphics.gofplots import qqplot

# %%
qqplot(ap['lang.num'],line='s')

# %%
#Normalisation

# %%
ap.head(2)

# %%
ap["lang.num"].plot.hist()

# %%
ap["sup_devices.num"].hist()

# %%
nor=["lang.num","rating_count_tot"]
st=["user_rating_ver","rating_count_ver"]

# %%
for i  in st:
    print("mean of column:",i," is ",ap[i].mean()," and standard deviation is",ap[i].std())

# %%
for i in st: #standerdization
    ap[i]=(ap[i]-ap[i].mean())/ap[i].std()

# %%
for i  in st:
    print("After standdaisation,mean of column:",i," is ",ap[i].mean()," and stander deviation is",ap[i].std())

# %%
ap["lang.num"].hist()

# %%
ap["sup_devices.num"].hist()

# %%
ap.head(10)

# %%
for i in nor:
    ap[i]=(ap[i]-ap[i].min())/(ap[i].max()-ap[i].min()) #Normalization of data

# %%
ap.head(10)

# %%
ap["lang.num"].hist()

# %%
ap["user_rating"].plot.hist()

# %%
from matplotlib import pyplot
from statsmodels.graphics.gofplots import qqplot

# %%
qqplot(ap['lang.num'],line='s')

# %%
#hypothesis testing for "user_rating_ver"  column

# %%
pop_mean=ap["user_rating_ver"].mean()
print(pop_mean)

# %%
sample=ap["user_rating_ver"].sample(500)

# %%
sample_mean=sample.mean()
print(sample_mean)

# %%
std_dev=sample.std()
print(std_dev)

# %%
from scipy.stats import norm
from math import sqrt
#one sided hypothesis test(for smaller than in NULL hypothesis)
def one_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha):
    actual_z = abs(norm.ppf(alpha))
    hypo_z = (sample_mean - pop_mean) / (std_dev/sqrt(sample_size))
    print('actual z value :', actual_z)
    print('hypothesis z value :', hypo_z, '\n')
    if hypo_z >= actual_z:
         print('True')
    else:
         print('False')
    
alpha = 0.05
#sample_mean = 58.995
#pop_mean = 60.466
sample_size = 500
#std_dev = 33.2419

print('H0 : μ <=', pop_mean)
print('H1 : μ >', pop_mean)
print('alpha value is :', alpha, '\n')

reject = one_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha)
if reject:
    print('Reject NULL hypothesis')
else:
    print('Failed to reject NULL hypothesis')
#variation with different parameters can be shown here

# %%
from scipy.stats import norm
from math import sqrt


def two_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha):
    actual_z = abs(norm.ppf(alpha/2))
    hypo_z = (sample_mean - pop_mean) / (std_dev/sqrt(sample_size))
    print('actual z value :', actual_z)
    print('hypothesis z value :', hypo_z, '\n')
    if hypo_z >= actual_z:
         print('True')
    else:
         print('False')

alpha = 0.05
sample_size =  600
pop_mean=4.06787550368209
std_dev=0.8445813372734086
sample_mean=4.103


print('H0 : μ =', pop_mean)
print('H1 : μ !=', pop_mean)
print('alpha value is :', alpha, '\n')

reject = two_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha)
if reject:
    print('Reject NULL hypothesis')
else:
    print('Failed to reject NULL hypothesis')
#variation with different parameters can be shown here

# %%
#hypothesis testing for "rating_count_ver"  column

# %%
pop_mean=ap["rating_count_ver"].mean()
print(pop_mean)

# %%
sample=ap["rating_count_ver"].sample(500)

# %%
sample_mean=sample.mean()
print(sample_mean)

# %%
std_dev=sample.std()
print(std_dev)

# %%
from scipy.stats import norm
from math import sqrt
#one sided hypothesis test(for smaller than in NULL hypothesis)
def one_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha):
    actual_z = abs(norm.ppf(alpha))
    hypo_z = (sample_mean - pop_mean) / (std_dev/sqrt(sample_size))
    print('actual z value :', actual_z)
    print('hypothesis z value :', hypo_z, '\n')
    if hypo_z >= actual_z:
         print('True')
    else:
         print('False')
    
alpha = 0.05
#sample_mean = 58.995
#pop_mean = 60.466
sample_size = 500
#std_dev = 33.2419

print('H0 : μ <=', pop_mean)
print('H1 : μ >', pop_mean)
print('alpha value is :', alpha, '\n')

reject = one_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha)
if reject:
    print('Reject NULL hypothesis')
else:
    print('Failed to reject NULL hypothesis')
#variation with different parameters can be shown here

# %%
from scipy.stats import norm
from math import sqrt


def two_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha):
    actual_z = abs(norm.ppf(alpha/2))
    hypo_z = (sample_mean - pop_mean) / (std_dev/sqrt(sample_size))
    print('actual z value :', actual_z)
    print('hypothesis z value :', hypo_z, '\n')
    if hypo_z >= actual_z:
         print('True')
    else:
         print('False')

alpha = 0.05


sample_size =  600

print('H0 : μ =', pop_mean)
print('H1 : μ !=', pop_mean)
print('alpha value is :', alpha, '\n')

reject = two_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha)
if reject:
    print('Reject NULL hypothesis')
else:
    print('Failed to reject NULL hypothesis')
#variation with different parameters can be shown here

# %%
samp=ap.head(600) # sample data of dataset

# %%
samp

# %%
import numpy as np 
import matplotlib.pyplot as plt
from math import sqrt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error as RMSE
from scipy.stats.stats import pearsonr

# %%
ap.corr(method='pearson')

# %%
sns.heatmap(ap.corr())

# %%
corr,_= pearsonr(ap['rating_count_tot'],ap['user_rating'])
print('pearsons correlation:%.3f'%corr)  #pearson's coefficient of  rating_count_tot v/s user_rating

# %%
corr,_=pearsonr(ap['rating_count_ver'],ap['lang.num'])
print('pearsons correlation:%.3f'%corr)  #pearson's coefficient of  rating_count_ver v/s lang.num

# %%
#using python in built functions

def linear_regression(x, y):
    x = [[i] for i in x]
    # Create linear regression object
    regr = linear_model.LinearRegression()

    # Train the model using the training sets
    regr.fit(x, y)
    
    #prediction 
    y_preds = regr.predict(x)
    
    print('Coefficients: \n', regr.coef_)
    print("RMSE: %.2f" % RMSE(y, y_preds))
    
    plt.scatter(x, y,  color='m')
    plt.plot(x, y_preds, color='g')
    plt.show()
    
x = samp['rating']
y = samp['lang.num'] 
linear_regression(x, y)

# %%
#using python in built functions

def linear_regression(x, y):
    x = [[i] for i in x]
    # Create linear regression object
    regr = linear_model.LinearRegression()

    # Train the model using the training sets
    regr.fit(x, y)
    
    #prediction 
    y_preds = regr.predict(x)
    
    print('Coefficients: \n', regr.coef_)
    print("RMSE: %.2f" % RMSE(y, y_preds))
    
    plt.scatter(x, y,  color='r')
    plt.plot(x, y_preds, color='y')
    plt.show()
    
x = ap['user_rating']
y = ap['rating_count_ver'] 
linear_regression(x, y)

# %%
#using python in built functions

def linear_regression(x, y):
    x = [[i] for i in x]
    # Create linear regression object
    regr = linear_model.LinearRegression()

    # Train the model using the training sets
    regr.fit(x, y)
    
    #prediction 
    y_preds = regr.predict(x)
    
    print('Coefficients: \n', regr.coef_)
    print("RMSE: %.2f" % RMSE(y, y_preds))
    
    plt.scatter(x, y,  color='b')
    plt.plot(x, y_preds, color='r')
    plt.show()
    
x = ap['user_rating']
y = ap['user_rating_ver'] 
linear_regression(x, y)

# %%
#using python in built functions

def linear_regression(x, y):
    x = [[i] for i in x]
    # Create linear regression object
    regr = linear_model.LinearRegression()

    # Train the model using the training sets
    regr.fit(x, y)
    
    #prediction 
    y_preds = regr.predict(x)
    
    print('Coefficients: \n', regr.coef_)
    print("RMSE: %.2f" % RMSE(y, y_preds))
    
    plt.scatter(x, y,  color='b')
    plt.plot(x, y_preds, color='r')
    plt.show()
    
x = ap['user_rating']
y = ap['user_rating_ver'] 
linear_regression(x, y)

# %%
ap.corr(method='pearson')

# %%
sns.heatmap(ap.corr)
